# %%
import numpy as np
import pandas as pd
import os

from sqlalchemy.util import ordered_column_set

# %%
path = '../data/Subject'
years = np.arange(2018,2026)
names_N =  os.listdir(f'{path}/{years[0]}')
names_D = os.listdir(f'{path}/Detailed')

# %%
for year in years:
    for name in names_N:
        df = pd.read_csv(f'{path}/{year}/{name}')
        df = df.loc[df['Unnamed: 0'] == 'Dokuz Eylul University']
        df['year'] = year
        df['name'] = name
        if year == 2018:
            df_all = df
            
        else:
            df_all = pd.concat([df_all, df])
# Out:
# C:\Users\firat\AppData\Local\Temp\ipykernel_3544\4201709916.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all = pd.concat([df_all, df])
# C:\Users\firat\AppData\Local\Temp\ipykernel_3544\4201709916.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all = pd.concat([df_all, df])

# %%
df_all = df_all[ordered_columns]

# %%
df_all
# Out:
#                               name  year              Unnamed: 0  \
# 0       Social Sciences values.csv  2018  Dokuz Eylul University
# 3       Social Sciences values.csv  2018  Dokuz Eylul University
# 0   Arts and Humanities scores.csv  2019  Dokuz Eylul University
# 4   Arts and Humanities scores.csv  2019  Dokuz Eylul University
# 0   Arts and Humanities values.csv  2019  Dokuz Eylul University
# ..                             ...   ...                     ...
# 11           Psychology values.csv  2025  Dokuz Eylul University
# 0       Social Sciences scores.csv  2025  Dokuz Eylul University
# 11      Social Sciences scores.csv  2025  Dokuz Eylul University
# 0       Social Sciences values.csv  2025  Dokuz Eylul University
# 11      Social Sciences values.csv  2025  Dokuz Eylul University
#
#    Doctorate Bachelor Awarded Doctorate awarded to academic staff  \
# 0                         NaN                                 NaN
# ...

# %%
df_all.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df_all.to_excel('../data/result/DEU_Subjects.xlsx')

# %%
for name in names_D:
    df = pd.read_csv(f'{path}/Detailed/{name}')
    df = df.loc[df['Institutions'] == 'Dokuz Eylul University']
    df['name'] = name
    if name == names_D[0]:
        df_all = df
    else:
        df_all = pd.concat([df_all, df])

# %%
df_all.drop('Institutions', axis = 1, inplace = True)

# %%
df_all
# Out:
#    2018  2019  2020  2021  2022  2023  2024  2025  \
# 0   NaN   NaN   NaN  33.7  24.1  27.9  33.2  46.4
# 0   NaN   NaN   NaN   NaN   NaN   NaN  19.5   NaN
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0   NaN   NaN  27.3   NaN   NaN   NaN  29.7   NaN
# 0   NaN   NaN   NaN  23.9  16.8  22.1  21.0  20.2
# 0   NaN   NaN  16.0  15.4  17.3   NaN   NaN   NaN
# 0  25.4  12.1  34.9  36.0  33.4  14.3  16.9  17.4
# 0  19.7  25.8  31.4  17.5  23.0  32.1  31.1  23.8
# 0   NaN   NaN  10.8  13.5  15.3   NaN   NaN   NaN
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  20.5
# 0   NaN   NaN   NaN  28.3  17.7  11.7  16.7  21.9
# 0  12.0  12.0  16.1  13.5  13.8  13.2  23.6  21.3
# 0  19.0  18.8  19.6  14.3  24.5  25.5  16.2  16.5
# 0  21.7  27.7  26.2  18.0  23.4  29.6  27.2  29.2
# 0   NaN   NaN  18.4  13.9  23.4   NaN  24.6  28.9
# 0  12.9  28.9  13.2  13.5  30.6  32.4  15.6  18.1
# ...

# %%
ordered_column = ['name','2018','2019','2020','2021','2022','2023','2024','2025']
df_all = df_all[ordered_column]

# %%
df_all.to_excel('../data/result/DEU_Subjects_Detailed.xlsx')

# %%
df = pd.read_excel('../data/result/DEU_Subjects.xlsx')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
# if name includes 'values then drop this row'

df = df[~df['name'].str.contains('values')]

# %%
# if all values is null expect name and year column then drop this row
df = df.dropna(subset = df.columns[2:], how = 'all')

# %%
df
# Out:
#                                name  year  Doctorate Bachelor Awarded  \
# 10   Clinical and Health scores.csv  2019                        45.2
# 11   Clinical and Health scores.csv  2019                        45.2
# 18             Education scores.csv  2019                        43.5
# 19             Education scores.csv  2019                        43.5
# 22           Engineering scores.csv  2019                        41.2
# ..                              ...   ...                         ...
# 299          Engineering scores.csv  2025                         NaN
# 312    Physical Sciences scores.csv  2025                         NaN
# 313    Physical Sciences scores.csv  2025                         NaN
# 320      Social Sciences scores.csv  2025                         NaN
# 321      Social Sciences scores.csv  2025                         NaN
#
#      Doctorate awarded to academic staff  \
# 10                                  26.2
# ...

# %%
df.to_excel('../data/result/DEU_Subjects.xlsx')

# %%
df.loc[df['year'] == 2024]
# Out:
#                                   name  year  Doctorate Bachelor Awarded  \
# 236  Business and Economics scores.csv  2024                         NaN
# 237  Business and Economics scores.csv  2024                         NaN
# 240     Clinical and Health scores.csv  2024                         NaN
# 241     Clinical and Health scores.csv  2024                         NaN
# 248               Education scores.csv  2024                         NaN
# 249               Education scores.csv  2024                         NaN
# 252             Engineering scores.csv  2024                         NaN
# 253             Engineering scores.csv  2024                         NaN
# 260           Life Sciences scores.csv  2024                         NaN
# 261           Life Sciences scores.csv  2024                         NaN
# 266       Physical Sciences scores.csv  2024                         NaN
# 267       Physical Sciences scores.csv  2024                         NaN
# ...
