# %%
import numpy as np
import pandas as pd

# %%
df_des = pd.read_csv('../data/Cluster/Cluster Descriptions.csv')
df_ins = pd.read_csv('../data/Cluster/Institution Clusters.csv')

# %%
df_des
# Out:
#                Cluster name  \
# 0                 Old stars
# 1  International powerhouse
# 2  Life science challengers
# 3    Technology challengers
# 4      Effective publishers
# 5            Core strengths
# 6            Regional stars
# 7      Developing expertise
# 8         Asian challengers
# 9          Emerging talents
#
#                                          Description  Number of institutions  \
# 0  The Old Stars form the core group of instituti...                      21
# 1  Dominated by the US but with significant UK an...                      85
# 2  Sitting just behind the Old Stars and Internat...                     123
# 3  Sitting just behind the Old Stars and Internat...                     156
# 4  The Effective Publishers are a group of Univer...                     148
# 5  The Core Strengths group represents the solid ...                     282
# 6  The most established institutions in Asia and ...                      48
# ...

# %%
df_deu = df_ins.iloc[:, 1:]

# %%
df_ins
# Out:
#                                           Institution               Cluster
# 0                              Dokuz Eylul University      Emerging talents
# 1                                 Makerere University     Asian challengers
# 2                                 Kharazmi University  Developing expertise
# 3                 UFG - Universidade Federal de Goiás      Emerging talents
# 4                        Prince of Songkla University     Asian challengers
# 5                        Universidad Austral de Chile      Emerging talents
# 6                                  University of Pecs      Emerging talents
# 7                            University of Lethbridge      Emerging talents
# 8       Universidad Nacional de Educacion a Distancia     Asian challengers
# 9                              De La Salle University     Asian challengers
# 10                          Pusan National University     Asian challengers
# ...
