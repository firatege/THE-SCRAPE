# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
pillar_det = pd.read_csv('../data/wur_overview_2025/Pillar details.csv')
pillar_scores = pd.read_csv('../data/wur_overview_2025/Pillar scores.csv')
change_year = pd.read_csv('../data/wur_overview_2025/Change over year.csv')

# %%
# Check the data
pillar_det
# Out:
#                    Pillar                       Metric    Rank  Score  \
# 0                Teaching                          NaN  1072.0   25.2
# 1                     NaN     Doctorate bachelor ratio     NaN   61.8
# 2                     NaN        Doctorate staff ratio     NaN   75.2
# 3                     NaN         Institutional income     NaN   43.4
# 4                     NaN          Student staff ratio     NaN   17.8
# 5                     NaN          Teaching reputation     NaN    1.2
# 6    Research Environment                          NaN  1254.0   14.5
# 7                     NaN        Research productivity     NaN   21.8
# 8                     NaN              Research income     NaN   51.0
# 9                     NaN          Research reputation     NaN    1.2
# 10       Research Quality                          NaN  1700.0   25.8
# 11                    NaN              Citation impact     NaN   17.0
# ...

# %%
pillar_scores
# Out:
#                Unnamed: 0  Teaching  Research Environment  Research Quality  \
# 0  Dokuz Eylul University      25.2                  14.5              25.8
# 1         Worldwide: Top*      56.7                  54.6              99.7
# 2          Worldwide: 75%      34.2                  28.8              72.5
# 3       Worldwide: Median      25.6                  17.1              52.3
# 4          Worldwide: 25%      19.2                  11.6              30.7
# 5      Worldwide: Bottom*       9.0                   2.8               3.4
#
#    Industry  International Outlook
# 0      64.6                   29.0
# 1     100.0                   99.3
# 2      68.3                   64.3
# 3      41.7                   45.3
# 4      23.0                   32.0
# 5      15.7                   16.4

# %%
change_year
# Out:
#    Year  2016  2017   2018   2019   2020   2021   2022       2023       2024  \
# 0  Rank   NaN   NaN  1001+  1001+  1001+  1001+  1201+  1201-1500  1201-1500
#
#     2025
# 0  1501+
